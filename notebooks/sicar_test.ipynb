# %%
import pandas as pd
import geopandas as gpd
from shapely import wkt
from hooks.http_sicar_hook import HttpSicarHook

# %%
sicar = HttpSicarHook()

# %%
data = sicar.get_sicar_data("sc")

# %%
df = gpd.GeoDataFrame(
    data,
    geometry=[wkt.loads(g) if g else None for g in (r["geometry"] for r in data)],
    crs="EPSG:4326",
)

# %%
df

# %%
df["geometry"][9]
# Out:
# <MULTIPOLYGON (((-52.292 -27.054, -52.291 -27.053, -52.291 -27.052, -52.29 -...>
